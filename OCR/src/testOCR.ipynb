# %%
from OCR import OCR
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from OCR import OCR
#
# File f:\CUFE\4th year\GP\vidseek\OCR\src\OCR.py:8
#       5 import joblib
#       7 from ovo_svm import OvO_SVM
# ----> 8 from ..utils.Hog import HoG, calc_gradients, predict_char
#       9 from utils.MSER import merge_boxes, sort_word_chars, remove_image_border_box, remove_holes, remove_large_boxes
#      10 from utils.text_detector import extract_word_images
#
# ImportError: attempted relative import with no known parent package
