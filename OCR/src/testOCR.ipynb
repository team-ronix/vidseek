# %%
from OCR import OCR
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from OCR import OCR
#
# File f:\CUFE\4th year\GP\vidseek\OCR\src\OCR.py:10
#       6 import sys
#       8 # sys.path.append(os.path.dirname(os.path.abspath(__file__)))
# ---> 10 from ..utils.ovo_svm import OvO_SVM
#      11 from ..utils.Hog import HoG, calc_gradients, predict_char
#      12 from ..utils.MSER import merge_boxes, sort_word_chars, remove_image_border_box, remove_holes, remove_large_boxes
#
# ImportError: attempted relative import with no known parent package
