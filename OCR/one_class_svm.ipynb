# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import OneClassSVM
import joblib

# %%
char_hog_features = joblib.load("./features/x_char_features_hog.joblib")

# %%
oc_svm = OneClassSVM(kernel='rbf', nu=0.05, verbose=True)

# %%
oc_svm.fit(char_hog_features)

# %%
joblib.dump(oc_svm, "./models/one_class_svm.joblib")
